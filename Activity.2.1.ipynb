# %% [markdown]
# # Activity 2.1. Linear Regression
# ## Introduction
# In this activity you learn how to use an optimization algorithm, called Stochastic Gradient Descent (SGD), to build a linear model for regression. In Activity 2, you will be asked to expand the linear regression implementation and develop ridge regression algorithm (linear regression with $\ell_2$ regularization).
#
# ## Instructions
# <ol>
# 	<li>Generate a synthetic dataset suitable for regression and divide it to train and test sets,
#     <li>Choose and implement a basis function $\pmb{\phi}$, and initialize weight vector $\pmb{w}$, learning rate $\eta$ and termination threshold $\epsilon$.</li>
# 	<li> Use the above function and repeat the following until the difference between the old and new weight vectors becomes small (i.e., $d(\pmb{w}^{\tau+1}, \pmb{w}^{\tau}) \leq\epsilon$):
# <ol>
# 	<li>Shuffle the training data</li>
# 	<li>For each datapoint in the training data do:
# <ol>
# 	<li>$\pmb{w}^{(\tau+1)} := \pmb{w}^{(\tau)} + \eta (t - {\pmb{w}^{(\tau)}}.\pmb{\phi}_n) \pmb{\phi}_n$</li>
# </ol>
# </li>
# </ol>
# </li>
# 	<li>Plot the weights $\pmb{w}^{\tau}$ vs. iteration number $\tau$</li>
#     <li>Plot the training and testing errors vs. iteration number $\tau$.</li>
#     <li>Repeat the above experiments using different datasets, random seeds, initial weights, and $\epsilon$ value</li>
# </ol>

# %% [markdown]
# ## Implementation
# ### Dataset
# Let start with loading libraries and generateing a synthetic dataset, as follows. Here, we generate $N$ data points generated uniformly at random (using `runif`). We then choose a weight vector (called `coeff`) using which we produce the corresponding target value for each data point.  In the training time, we pretend that we don't know the weight vector and we try to learn it using the generated training dataset.

# %%
library(ggplot2) # for plotting functions.
library(reshape2) # for melt and cast functions
set.seed(1234) # to make the results of stochastic methods reproducible

# geberate N x D data samples
N <- 200 # number of all data point (test and train)
D <- 4 # number of features/attributes
data <- data.frame(matrix(runif(D*N), nrow=N, ncol=D))

# generate the labels
coeff <- matrix(c(-5,-3,4,5,10), D+1, 1) # the real coefficient to be estimated
data <- cbind(data,'Y'=as.matrix(cbind(1,data[,1:D])) %*% coeff) # bind Y column multiplying data by transpose coeff to x columns
# add gaussian noise the labels (just to make it a little bit more challenging)
data$Y <- data$Y + rnorm(N, mean = 0, sd =1)
pairs(data)
# Out:
# plot without title

# %%
#as.matrix(cbind(1,data[,1:D]))

# %% [markdown]
# Now, divide the dataset into testing and training sets

# %%
# divide data into training and testing sets
train.len <- N/2
train.index <- sample(1:N,train.len)
train.data <- data[train.index,  1:D]
train.label <- data[train.index, 'Y']
test.data <- data[-train.index, 1:D]
test.label <- data[-train.index, 'Y']

# %% [markdown]
# ## Implementation
# Now, based on the instruction, we initialize the parameter values.

# %% [markdown]
# ### Auxilary Functions
# To produce a clean and readable code, let us first define some auxiliary function that calculate the prediction and cost based on the projected data and estimated coefficients.

# %%
# auxiliary function to calculate labels based on the estimated coefficients
predict_func <- function(Phi, w){
    return(Phi%*%w) #phi x w_transpose # this will solve basically give us the model predictions 
    # which are w x Phi switched around because of matrix dimensions
} 

# auxiliary function to calculate a cost function
error_func <- function (Phi, w, label){
    return(sum((predict_func(Phi, w) - label)^2)/2)
}

# %% [markdown]
# ### Initialization

# %%
# project data using a basis function (identical here)
Phi <- as.matrix(cbind('X0'=1, train.data)) # add a column of 1 as X_0

T <- train.label # rename just for conviniance
tau.max <- 10000 # maximum number of iterations
eta <- 0.01 # learning rate
epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)

#create empty W matrix (no.of iterations x no. of phi's /basis function terms) (stores coeff
# for each iteration)
W <- matrix(,nrow=tau.max, ncol=ncol(Phi)) # be used to store the estimated oefficients

W[1,] <- runif(ncol(Phi)) # initial weight (any better idea?) uses uniform distribution
#create single column to store errors for each iteration (for graphing/tracking convergence)
error <- data.frame('tau'=1:tau.max)  # to be used to trace the test and training errors in each iteration

tau <- 1 # iteration counter
terminate <- FALSE

# %% [markdown]
# ### Main Loop

# %%
while(!terminate){
    # check termination criteria:
    terminate <- tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon
    
    #shuffling data part is for Stochastic part
    # shuffle data:
    train.index <- sample(1:train.len, train.len, replace = FALSE)
    Phi <- Phi[train.index,]
    T <- T[train.index] # (training labels)
    
    # for each datapoint:
    for (i in 1:train.len){
        # check termination criteria: at each sampling can converge inside an iteration
        if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon) {terminate<-TRUE;break}
        #predict a label based on current coeffs (w's) (current iteration row) and single phi row/datapoint
        t_pred = predict_func(Phi[i,], W[tau,])
        # for each coefficient:
        for (j in 1: ncol(W)){
            # update the coefficient (for this iteration's row):
            W[(tau+1),j] <- W[tau,j] + eta * (T[i]-t_pred) * Phi[i,j]
        }
        
        # record the error: # use phi x W as per predictions and comapre with test and train labels
        error[tau, 'train'] <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        error[tau, 'test'] <- error_func(as.matrix(cbind(1, test.data)), W[tau,],test.label)
        
        # update the counter: (i.e. new iteration)
        tau <- tau + 1        
    }
}
#melt error for visualisations
error.m <- melt(error[1:tau,], id='tau')

# the  final result is:
w <- W[tau,]
cat('The  real coefficents are:',coeff,'\nThe  final coefficents are:',w)
# Out:
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.922834 -3.322868 4.27025 4.820343 9.94146

# %% [markdown]
# ### Visualizations

# %% [markdown]
#   Let's plot the errors of the learned weight vectors over the training iterations on the training and test sets.

# %%
ggplot(data=error.m, aes(x=tau, y=value, color=variable)) +
    geom_line() + ggtitle('Test and Train Error') +
    scale_color_discrete(guide = guide_legend(title = 'Errors')) +theme_minimal()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_path).”
# plot without title

# %% [markdown]
# Now let's plot the elements of the learned weight vectors over the training iterations.

# %%
W.m <- as.data.frame(W); names(W.m)<-c('w0','w1','w2','w3','w4')
W.m$tau<-1:nrow(W)
W.m <-melt(W.m, id='tau'); names(W.m) <- c('tau', 'coefficients', 'values')
ggplot(data=W.m, aes(x=tau, y=values, color=coefficients)) + geom_line() + ggtitle('Estimated Coefficients') + theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Discussions
# <ol>
#
# 	<li>How the learning rate can affect the convergence rate (i.e., when the algorithm stops improving) and prediction error? Choose some other constant values for the learning rate and investigate their effects.</li>
# 	<li>Do you believe having different learning rates at different iterations of the main learning loop can help? If it matters, is it better to have large values at start and smaller when close to finish or the other way around? Validate your intuition using monotonically increasing or decreasing learning rates as functions of $\tau$ (e.g. try $\frac{a}{b+\tau}$ for different values of $a$ and $b$).</li>
# 	<li>Modify your code and develop a batch gradient descent. The main difference is that you do not need to shuffle the training data, but have to include all training samples in the calculation of the weight updates in each iterations. Compare and discuss the convergence rates and final training error for SGD and batch GD. </li>
# </ol>

# %% [markdown]
# 1.- How the learning rate can affect the convergence rate (i.e., when the algorithm stops improving) and prediction error? Choose some other constant values for the learning rate and investigate their effects.

# %%
# project data using a basis function (identical here)
Phi <- as.matrix(cbind('X0'=1, train.data)) # add a column of 1 as X_0

T <- train.label # rename just for conviniance
tau.max <- 10000 # maximum number of iterations
for (eta in c(0.001,0.005,0.01,0.05,0.1,0.5,0.75)) {
#eta <- 0.01 # learning rate
#epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)
    epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)

#create empty W matrix (no.of iterations x no. of phi's /basis function terms) (stores coeff
# for each iteration)
W <- matrix(,nrow=tau.max, ncol=ncol(Phi)) # be used to store the estimated oefficients

W[1,] <- runif(ncol(Phi)) # initial weight (any better idea?) uses uniform distribution
#create single column to store errors for each iteration (for graphing/tracking convergence)
error <- data.frame('tau'=1:tau.max)  # to be used to trace the test and training errors in each iteration

tau <- 1 # iteration counter
terminate <- FALSE


while(!terminate){
    # check termination criteria:
    terminate <- tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon
    
    #shuffling data part is for Stochastic part
    # shuffle data:
    train.index <- sample(1:train.len, train.len, replace = FALSE)
    Phi <- Phi[train.index,]
    T <- T[train.index] # (training labels)
    
    # for each datapoint:
    for (i in 1:train.len){
        # check termination criteria: at each sampling can converge inside an iteration
        
        if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon) {terminate<-TRUE;break}
        #predict a label based on current coeffs (w's) (current iteration row) and single phi row/datapoint
        t_pred = predict_func(Phi[i,], W[tau,])
        # for each coefficient:
        for (j in 1: ncol(W)){
            # update the coefficient (for this iteration's row):
            W[(tau+1),j] <- W[tau,j] + eta * (T[i]-t_pred) * Phi[i,j]
        }
        
        # record the error: # use phi x W as per predictions and comapre with test and train labels
        error[tau, 'train'] <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        error[tau, 'test'] <- error_func(as.matrix(cbind(1, test.data)), W[tau,],test.label)
        
        # update the counter: (i.e. new iteration)
        tau <- tau + 1        
    }
}
#melt error for visualisations
error.m <- melt(error[1:tau,], id='tau')

# the  final result is:
w <- W[tau,]
cat('\n\nLearning rate Eta',eta)
cat('\nThe  real coefficents are:',coeff,'\nThe  final coefficents are:',w)
cat('\nIterations taken:',tau,'Error:',error.m[tau-1,'value'])

}
# Out:
# Learning rate Eta 0.001
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.9014336 -2.039689 1.974221 2.623876 5.717244
# Iterations taken: 10000 Error: 188.7173
#
# Learning rate Eta 0.005
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.241533 -3.535884 3.898684 4.411715 9.551783
# Iterations taken: 10000 Error: 56.29386
#
# Learning rate Eta 0.01
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.93791 -3.328546 4.259951 4.79263 9.919919
# Iterations taken: 10000 Error: 53.7782
#
# Learning rate Eta 0.05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.240652 -3.476605 4.190577 4.734969 9.894937
# Iterations taken: 10000 Error: 64.42874
#
# Learning rate Eta 0.1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.124967 -3.355158 4.245763 4.803663 9.848252
# Iterations taken: 10000 Error: 54.85379
#
# Learning rate Eta 0.5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.873275 -2.368827 5.554362 3.991332 10.51699
# Iterations taken: 10000 Error: 78.87139
#
# Learning rate Eta 0.75
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -2.318391 0.283759 3.628488 6.170887 11.25932
# Iterations taken: 10000 Error: 400.7771

# %% [markdown]
# 2.- Do you believe having different learning rates at different iterations of the main learning loop can help? If it matters, is it better to have large values at start and smaller when close to finish or the other way around? Validate your intuition using monotonically increasing or decreasing learning rates as functions of $\tau$ (e.g. try $\frac{a}{b+\tau}$ for different values of $a$ and $b$).

# %% [markdown]
# It would be best to use a large value of learning rate initially then we can reduce it rapidly to get fine adjustments to the coeff rather than overshooting the real coeffecients

# %%
# project data using a basis function (identical here)
Phi <- as.matrix(cbind('X0'=1, train.data)) # add a column of 1 as X_0

T <- train.label # rename just for conviniance
tau.max <- 10000 # maximum number of iterations
#for (eta in c(0.001,0.005,0.01,0.05,0.1,0.5,0.75)) {
for (a in c(1,5,10,50,100,500,1000)) { #
for (b in a*c(0.01,0.1,1,10,100,1000,10000)) { #
#for (a in c(100,250,500,750,1000)) {
#for (b in c(100,250,500,750,1000)) {
#a = 1000
#b = 100

#for (eta in c(0.5,0.75)) {
#eta <- 0.01 # learning rate
#eta_base = eta
    #epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)
epsilon <- 55 # a threshold on the cost (to terminate the process)
    
    
#create empty W matrix (no.of iterations x no. of phi's /basis function terms) (stores coeff
# for each iteration)
W <- matrix(,nrow=tau.max, ncol=ncol(Phi)) # be used to store the estimated oefficients

W[1,] <- runif(ncol(Phi)) # initial weight (any better idea?) uses uniform distribution
#create single column to store errors for each iteration (for graphing/tracking convergence)
error <- data.frame('tau'=1:tau.max)  # to be used to trace the test and training errors in each iteration

tau <- 1 # iteration counter
terminate <- FALSE


while(!terminate){
    # check termination criteria:
    terminate <- tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon
    eta <- a/ (b+tau)
    #shuffling data part is for Stochastic part
    # shuffle data:
    train.index <- sample(1:train.len, train.len, replace = FALSE)
    Phi <- Phi[train.index,]
    T <- T[train.index] # (training labels)
    #print (W[tau,])
    #print (T)
   #print (Phi)
    #cat('\nLearning rate Eta',eta)
    #cat('\nPred',predict_func(Phi, W[tau,])) 
    #cat('\nError',error_func(Phi, W[tau,],T))
    
    # for each datapoint:
    for (i in 1:train.len){
        # check termination criteria: at each sampling can converge inside an iteration
        #cat('\ntau =',tau)
        if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon | mean(predict_func(Phi, W[tau,])) >1e200 ) {terminate<-TRUE;break}
        #predict a label based on current coeffs (w's) (current iteration row) and single phi row/datapoint
        t_pred = predict_func(Phi[i,], W[tau,])
        # for each coefficient:
        for (j in 1: ncol(W)){
            # update the coefficient (for this iteration's row):
            W[(tau+1),j] <- W[tau,j] + eta * (T[i]-t_pred) * Phi[i,j]
        }
        
        # record the error: # use phi x W as per predictions and comapre with test and train labels
        error[tau, 'train'] <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        error[tau, 'test'] <- error_func(as.matrix(cbind(1, test.data)), W[tau,],test.label)
        
        # update the counter: (i.e. new iteration)
        tau <- tau + 1
        
    }
}
#melt error for visualisations
error.m <- melt(error[1:tau,], id='tau')

# the  final result is:
w <- W[tau,]
cat('\n\nLearning rate Eta',eta)
cat(' a = ',a, ' b = ',b)
cat('\nThe  real coefficents are:',coeff,'\nThe  final coefficents are:',w)
cat('\nIterations taken:',tau,'Error:',error.m[tau-1,'value'])

}
}
#}
#}
# Out:
# Learning rate Eta 0.0001009998 a =  1  b =  0.01
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -168120.8 -24307 -79318.28 258707.1 152040.8
# Iterations taken: 10000 Error: 419091544726
#
# Learning rate Eta 0.0001009989 a =  1  b =  0.1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 36.0388 39.43706 -45.53619 -247.7943 207.4504
# Iterations taken: 10000 Error: 434733.5
#
# Learning rate Eta 0.0001009897 a =  1  b =  1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -3.607135 -3.862867 4.17377 4.292592 8.569693
# Iterations taken: 10000 Error: 65.32535
#
# Learning rate Eta 0.000100898 a =  1  b =  10
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -1.397508 -2.966905 2.396111 2.978056 6.739697
# Iterations taken: 10000 Error: 133.6253
#
# Learning rate Eta 9.999e-05 a =  1  b =  100
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.2296701 -1.441315 1.762584 2.05925 3.791247
# Iterations taken: 10000 Error: 306.079
#
# Learning rate Eta 9.17347e-05 a =  1  b =  1000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.6730517 -0.03986712 1.391831 1.215232 2.824501
# Iterations taken: 10000 Error: 428.9639
#
# Learning rate Eta 5.024873e-05 a =  1  b =  10000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.8267668 0.2941377 0.9912029 1.302163 1.353077
# Iterations taken: 10000 Error: 556.6186
#
# Learning rate Eta 0.0005049969 a =  5  b =  0.05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -1.218417e+91 4.905534e+90 -7.253351e+90 1.445221e+91 1.055133e+91
# Iterations taken: 10000 Error: 1.638034e+183
#
# Learning rate Eta 0.000504974 a =  5  b =  0.5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -1.109516e+74 7.980952e+72 8.559422e+73 5.417256e+73 5.617501e+73
# Iterations taken: 10000 Error: 5.990955e+148
#
# Learning rate Eta 0.0005047446 a =  5  b =  5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.854651 -1.499009 2.743027 5.299129 10.92831
# Iterations taken: 10000 Error: 78.82456
#
# Learning rate Eta 0.0005024621 a =  5  b =  50
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -3.434668 -3.552621 3.422378 4.086958 8.936399
# Iterations taken: 10000 Error: 65.11084
#
# Learning rate Eta 0.000480723 a =  5  b =  500
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -1.53306 -3.103502 2.480143 3.02783 6.983912
# Iterations taken: 10000 Error: 124.2157
#
# Learning rate Eta 0.0003355479 a =  5  b =  5000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.2859478 -1.203814 1.432206 1.828014 4.03558
# Iterations taken: 10000 Error: 309.7879
#
# Learning rate Eta 8.347106e-05 a =  5  b =  50000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.46321 0.1178785 1.479253 0.7303062 1.090698
# Iterations taken: 10000 Error: 572.9996
#
# Learning rate Eta 0.001009989 a =  10  b =  0.1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.437312e+120 -4.326023e+120 -6.699438e+120 1.43839e+121 -6.644165e+120
# Iterations taken: 10000 Error: 1.344005e+243
#
# Learning rate Eta 0.001009897 a =  10  b =  1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 3.877917e+92 -1.702886e+92 -1.539887e+92 -2.722067e+92 -1.200422e+92
# Iterations taken: 10000 Error: 6.4522e+185
#
# Learning rate Eta 0.00100898 a =  10  b =  10
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 30.41104 -12.0564 -29.76369 -5.030878 -2.798888
# Iterations taken: 10000 Error: 6795.935
#
# Learning rate Eta 0.0009999 a =  10  b =  100
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.34354 -3.484152 3.952268 4.483881 9.629108
# Iterations taken: 10000 Error: 55.56229
#
# Learning rate Eta 0.000917347 a =  10  b =  1000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -2.620027 -3.518404 3.087807 3.567178 8.252387
# Iterations taken: 10000 Error: 81.56459
#
# Learning rate Eta 0.0005024873 a =  10  b =  10000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.2932072 -1.322379 1.806091 2.22092 4.452549
# Iterations taken: 10000 Error: 267.5805
#
# Learning rate Eta 9.099098e-05 a =  10  b =  1e+05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.6830849 0.150006 1.51139 1.565323 1.63115
# Iterations taken: 10000 Error: 503.4854
#
# Learning rate Eta 0.00504974 a =  50  b =  0.5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 4.832852e+175 -1.868549e+175 -2.16069e+175 -2.718134e+175 -2.232408e+175
# Iterations taken: 10000 Error: Inf
#
# Learning rate Eta 0.005047446 a =  50  b =  5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -3.45397e+114 1.327395e+114 1.544283e+114 1.93859e+114 1.592738e+114
# Iterations taken: 10000 Error: 4.839239e+229
#
# Learning rate Eta 0.005024621 a =  50  b =  50
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.822628 -2.970629 4.66786 5.315463 10.36014
# Iterations taken: 10000 Error: 56.35112
#
# Learning rate Eta 0.03843198 a =  50  b =  500
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.481665 -3.462205 3.912636 4.629036 9.748405
# Iterations taken: 875 Error: 55.58687
#
# Learning rate Eta 0.003355479 a =  50  b =  5000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.411409 -3.478069 4.00949 4.526084 9.67065
# Iterations taken: 10000 Error: 55.17726
#
# Learning rate Eta 0.0008347106 a =  50  b =  50000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.4758561 -1.947862 1.706209 2.296585 5.430668
# Iterations taken: 10000 Error: 213.6815
#
# Learning rate Eta 9.805825e-05 a =  50  b =  5e+05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 0.8402263 0.5449052 0.8773469 1.524924 1.645196
# Iterations taken: 10000 Error: 531.6482
#
# Learning rate Eta 0.9803922 a =  100  b =  1
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 3.148298e+200 5.92394e+198 3.47543e+199 1.142508e+200 2.192946e+200
# Iterations taken: 101 Error: Inf
#
# Learning rate Eta 0.0100898 a =  100  b =  10
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -3.13046e+117 1.208318e+117 1.395981e+117 1.758638e+117 1.445474e+117
# Iterations taken: 10000 Error: 3.97694e+235
#
# Learning rate Eta 0.02127207 a =  100  b =  100
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.468 -3.580716 4.040818 4.550182 9.748
# Iterations taken: 4644 Error: 55.37426
#
# Learning rate Eta 0.06246096 a =  100  b =  1000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.462733 -3.575602 4.120674 4.649245 9.624577
# Iterations taken: 697 Error: 55.07212
#
# Learning rate Eta 0.005681495 a =  100  b =  10000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.452239 -3.476764 4.022279 4.532598 9.698269
# Iterations taken: 7662 Error: 55.03153
#
# Learning rate Eta 0.0009099098 a =  100  b =  1e+05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.5136319 -2.195738 1.874485 2.356407 5.491802
# Iterations taken: 10000 Error: 203.7009
#
# Learning rate Eta 9.901961e-05 a =  100  b =  1e+06
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.083891 0.4738436 1.4314 0.8047072 1.447317
# Iterations taken: 10000 Error: 554.7593
#
# Learning rate Eta 83.33333 a =  500  b =  5
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 7.870905e+201 2.334421e+201 5.476307e+201 4.764192e+201 2.478527e+201
# Iterations taken: 92 Error: Inf
#
# Learning rate Eta 3.311258 a =  500  b =  50
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 2.970039e+200 9.679815e+199 2.807357e+200 5.484699e+199 3.197522e+200
# Iterations taken: 198 Error: Inf
#
# Learning rate Eta 0.3843198 a =  500  b =  500
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.862348 -3.4487 3.99933 4.7704 10.21489
# Iterations taken: 894 Error: 56.70455
#
# Learning rate Eta 0.08926977 a =  500  b =  5000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.556409 -3.42133 3.941368 4.7397 9.652381
# Iterations taken: 627 Error: 55.2624
#
# Learning rate Eta 0.008928412 a =  500  b =  50000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.450251 -3.460896 4.029217 4.552041 9.687115
# Iterations taken: 6001 Error: 55.04945
#
# Learning rate Eta 0.0009805825 a =  500  b =  5e+05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.522982 -2.2367 1.859616 2.42803 5.506216
# Iterations taken: 10000 Error: 201.6738
#
# Learning rate Eta 9.980237e-05 a =  500  b =  5e+06
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.062523 0.872237 0.8277566 1.252381 1.279532
# Iterations taken: 10000 Error: 581.7009
#
# Learning rate Eta 90.90909 a =  1000  b =  10
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 2.520987e+201 1.224698e+201 8.48685e+200 1.422162e+201 1.258272e+201
# Iterations taken: 90 Error: Inf
#
# Learning rate Eta 4.975124 a =  1000  b =  100
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.663006e+200 2.719162e+199 1.31055e+200 6.024075e+199 4.718245e+199
# Iterations taken: 178 Error: Inf
#
# Learning rate Eta 0.3844675 a =  1000  b =  1000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.212582 -2.789722 4.084603 4.950758 9.927302
# Iterations taken: 1639 Error: 176.5742
#
# Learning rate Eta 0.09522903 a =  1000  b =  10000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.515934 -3.581138 4.0516 4.776532 9.675671
# Iterations taken: 600 Error: 56.31383
#
# Learning rate Eta 0.009451707 a =  1000  b =  1e+05
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.450783 -3.45513 4.011629 4.541277 9.690165
# Iterations taken: 5890 Error: 55.24568
#
# Learning rate Eta 0.0009901961 a =  1000  b =  1e+06
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -0.63448 -2.212522 1.902482 2.307621 5.773089
# Iterations taken: 10000 Error: 192.9138
#
# Learning rate Eta 9.990109e-05 a =  1000  b =  1e+07
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: 1.216468 0.1578831 1.290093 1.013779 1.594213
# Iterations taken: 10000 Error: 529.2019

# %% [markdown]
# ratio of a = 1: b = 1000 seems to cause issues with divergence when a goes above 100 we get predictions in the 1e200+ which we have set a breakpoint to prevent the model from breaking as we get infinite error.

# %% [markdown]
# Best model performance with a/ (b+tau) learning rate
# Learning rate Eta 0.08926977 a =  500  b =  5000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.468437 -3.468477 4.099078 4.576367 9.648856
# Iterations taken: 603 Error: 56.18997

# %%
# project data using a basis function (identical here)
Phi <- as.matrix(cbind('X0'=1, train.data)) # add a column of 1 as X_0

T <- train.label # rename just for conviniance
tau.max <- 10000 # maximum number of iterations
#for (eta in c(0.001,0.005,0.01,0.05,0.1,0.5,0.75)) {
#for (a in c(1,5,10,50,100,500,1000)) { #
#for (b in a*c(0.01,0.1,1,10,100,1000,10000)) { #
#for (a in c(100,250,500,750,1000)) {
#for (b in c(100,250,500,750,1000)) {
a = 500
b = 5000

#for (eta in c(0.5,0.75)) {
#eta <- 0.01 # learning rate
#eta_base = eta
    #epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)
epsilon <- 55 # a threshold on the cost (to terminate the process)
    
    
#create empty W matrix (no.of iterations x no. of phi's /basis function terms) (stores coeff
# for each iteration)
W <- matrix(,nrow=tau.max, ncol=ncol(Phi)) # be used to store the estimated oefficients

W[1,] <- runif(ncol(Phi)) # initial weight (any better idea?) uses uniform distribution
#create single column to store errors for each iteration (for graphing/tracking convergence)
error <- data.frame('tau'=1:tau.max)  # to be used to trace the test and training errors in each iteration

tau <- 1 # iteration counter
terminate <- FALSE


while(!terminate){
    # check termination criteria:
    terminate <- tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon
    eta <- a/ (b+tau)
    #shuffling data part is for Stochastic part
    # shuffle data:
    train.index <- sample(1:train.len, train.len, replace = FALSE)
    Phi <- Phi[train.index,]
    T <- T[train.index] # (training labels)

    
    # for each datapoint:
    for (i in 1:train.len){
        # check termination criteria: at each sampling can converge inside an iteration
        #cat('\ntau =',tau)
        if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon | mean(predict_func(Phi, W[tau,])) >1e200 ) {terminate<-TRUE;break}
        #predict a label based on current coeffs (w's) (current iteration row) and single phi row/datapoint
        t_pred = predict_func(Phi[i,], W[tau,])
        # for each coefficient:
        for (j in 1: ncol(W)){
            # update the coefficient (for this iteration's row):
            W[(tau+1),j] <- W[tau,j] + eta * (T[i]-t_pred) * Phi[i,j]
        }
        
        # record the error: # use phi x W as per predictions and comapre with test and train labels
        error[tau, 'train'] <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        error[tau, 'test'] <- error_func(as.matrix(cbind(1, test.data)), W[tau,],test.label)
        
        # update the counter: (i.e. new iteration)
        tau <- tau + 1
        
    }
}
#melt error for visualisations
error.m <- melt(error[1:tau,], id='tau')

# the  final result is:
w <- W[tau,]
cat('\n\nLearning rate Eta',eta)
cat(' a = ',a, ' b = ',b)
cat('\nThe  real coefficents are:',coeff,'\nThe  final coefficents are:',w)
cat('\nIterations taken:',tau,'Error:',error.m[tau-1,'value'])

#}
#}
#}
#}
print(ggplot(data=error.m, aes(x=tau, y=value, color=variable)) +
    geom_line() + ggtitle('Test and Train Error') +
    scale_color_discrete(guide = guide_legend(title = 'Errors')) +theme_minimal())
W.m <- as.data.frame(W); names(W.m)<-c('w0','w1','w2','w3','w4')
W.m$tau<-1:nrow(W)
W.m <-melt(W.m, id='tau'); names(W.m) <- c('tau', 'coefficients', 'values')

print(ggplot(data=W.m, aes(x=tau, y=values, color=coefficients)) + geom_line() + ggtitle('Estimated Coefficients') + theme_minimal())
# Out:
# Learning rate Eta 0.09089256 a =  500  b =  5000
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -4.490307 -3.638348 4.007122 4.583079 9.870677
# Iterations taken: 600 Error: 55.01358
# Warning message:
# “Removed 2 rows containing missing values (geom_path).”Warning message:
# “Removed 47000 rows containing missing values (geom_path).”
# plot without title
# plot without title

# %% [markdown]
# 3.- Modify your code and develop a batch gradient descent. The main difference is that you do not need to shuffle the training data, but have to include all training samples in the calculation of the weight updates in each iterations. Compare and discuss the convergence rates and final training error for SGD and batch GD.

# %%
# project data using a basis function (identical here)
Phi <- as.matrix(cbind('X0'=1, train.data)) # add a column of 1 as X_0

T <- train.label # rename just for conviniance
tau.max <- 1000 # maximum number of iterations
#eta <- 0.01 # learning rate
eta <- 0.01 # learning rate
eta0 <- eta
epsilon <- 0.1 * mean(T) # a threshold on the cost (to terminate the process)

#create empty W matrix (no.of iterations x no. of phi's /basis function terms) (stores coeff
# for each iteration)
W <- matrix(,nrow=tau.max, ncol=ncol(Phi)) # be used to store the estimated oefficients

W[1,] <- runif(ncol(Phi)) # initial weight (any better idea?) uses uniform distribution
#create single column to store errors for each iteration (for graphing/tracking convergence)
error <- data.frame('tau'=1:tau.max)  # to be used to trace the test and training errors in each iteration
error0 <- 1e10
tau <- 1 # iteration counter
terminate <- FALSE


while(!terminate){
    # check termination criteria:
    terminate <- tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon
    
    #shuffling data part is for Stochastic part
    # shuffle data:
    train.index <- sample(1:train.len, train.len, replace = FALSE)
    Phi <- Phi[train.index,]
    T <- T[train.index] # (training labels)
    
    # for each datapoint:
    #for (i in 1:train.len){
        # check termination criteria: at each sampling can converge inside an iteration
        if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon) {terminate<-TRUE;break}
        #predict a label based on current coeffs (w's) (current iteration row) and single phi row/datapoint
        t_pred = predict_func(Phi, W[tau,])
        # for each coefficient:
        for (j in 1: ncol(W)){
            # update the coefficient (for this iteration's row):
            if (tau >= tau.max | error_func(Phi, W[tau,],T)<=epsilon) {terminate<-TRUE;break}
            W[(tau+1),j] <- W[tau,j] + eta * (Phi[,j] %*%(T-t_pred) )
        }
        
        # record the error: # use phi x W as per predictions and comapre with test and train labels
        error[tau, 'train'] <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        error[tau, 'test'] <- error_func(as.matrix(cbind(1, test.data)), W[tau,],test.label)
        error1 <- error_func(as.matrix(cbind(1, train.data)), W[tau,],train.label)
        if (abs((error1 - error0)/error0)<=0.0000005) {terminate<-TRUE;break}
        error0 <- error1
    print (error1)
        # update the counter: (i.e. new iteration)
        tau <- tau + 1  
    if (error0 > (mean(T)*30)) {
    eta <- eta*0.99
        }
    else
        {
        eta <- max(eta*0.7,0.005)
    }

}
#melt error for visualisations
error.m <- melt(error[1:tau,], id='tau')

# the  final result is:
w <- W[tau,]
cat('The  real coefficents are:',coeff,'\nThe  final coefficents are:',w)
cat('\nIteration No.:',tau)
# Out:
# [1] 801.7506
# [1] 744.9682
# [1] 702.6554
# [1] 669.121
# [1] 639.1904
# [1] 608.5654
# [1] 574.1853
# [1] 534.4716
# [1] 489.3657
# [1] 440.1283
# [1] 388.9319
# [1] 338.3404
# [1] 290.7926
# [1] 248.1979
# [1] 211.7127
# [1] 181.7066
# [1] 157.8839
# [1] 139.4941
# [1] 125.5606
# [1] 115.0766
# [1] 107.1379
# [1] 101.0105
# [1] 96.14387
# [1] 92.15133
# [1] 89.48386
# [1] 87.61248
# [1] 85.86483
# [1] 84.21853
# [1] 82.66679
# [1] 81.20339
# [1] 79.82255
# [1] 78.51895
# [1] 77.28762
# [1] 76.12399
# [1] 75.0238
# [1] 73.98311
# [1] 72.99824
# [1] 72.06578
# [1] 71.18257
# [1] 70.34566
# [1] 69.55229
# [1] 68.79991
# [1] 68.08613
# [1] 67.40872
# [1] 66.7656
# [1] 66.15482
# [1] 65.57457
# [1] 65.02314
# [1] 64.49895
# [1] 64.0005
# [1] 63.52639
# [1] 63.07532
# [1] 62.64604
# [1] 62.2374
# [1] 61.84832
# [1] 61.47777
# [1] 61.1248
# [1] 60.78849
# [1] 60.46799
# [1] 60.1625
# [1] 59.87127
# [1] 59.59357
# [1] 59.32873
# [1] 59.07612
# [1] 58.83512
# [1] 58.60518
# [1] 58.38575
# [1] 58.17633
# [1] 57.97643
# [1] 57.78558
# [1] 57.60337
# [1] 57.42938
# [1] 57.26322
# [1] 57.10452
# [1] 56.95293
# [1] 56.80812
# [1] 56.66977
# [1] 56.53759
# [1] 56.41128
# [1] 56.29058
# [1] 56.17522
# [1] 56.06497
# [1] 55.95959
# [1] 55.85885
# [1] 55.76256
# [1] 55.6705
# [1] 55.58248
# [1] 55.49833
# [1] 55.41786
# [1] 55.34092
# [1] 55.26734
# [1] 55.19698
# [1] 55.12969
# [1] 55.06533
# [1] 55.00378
# [1] 54.94491
# [1] 54.8886
# [1] 54.83473
# [1] 54.78321
# [1] 54.73392
# [1] 54.68677
# [1] 54.64166
# [1] 54.59851
# [1] 54.55723
# [1] 54.51773
# [1] 54.47994
# [1] 54.44379
# [1] 54.40919
# [1] 54.37609
# [1] 54.34442
# [1] 54.31412
# [1] 54.28512
# [1] 54.25738
# [1] 54.23083
# [1] 54.20542
# [1] 54.18111
# [1] 54.15784
# [1] 54.13558
# [1] 54.11427
# [1] 54.09388
# [1] 54.07437
# [1] 54.0557
# [1] 54.03783
# [1] 54.02073
# [1] 54.00436
# [1] 53.98869
# [1] 53.9737
# [1] 53.95936
# [1] 53.94562
# [1] 53.93248
# [1] 53.9199
# [1] 53.90787
# [1] 53.89634
# [1] 53.88532
# [1] 53.87476
# [1] 53.86466
# [1] 53.85499
# [1] 53.84574
# [1] 53.83688
# [1] 53.8284
# [1] 53.82029
# [1] 53.81252
# [1] 53.80509
# [1] 53.79797
# [1] 53.79116
# [1] 53.78464
# [1] 53.77841
# [1] 53.77243
# [1] 53.76672
# [1] 53.76125
# [1] 53.75601
# [1] 53.751
# [1] 53.7462
# [1] 53.74161
# [1] 53.73721
# [1] 53.733
# [1] 53.72898
# [1] 53.72512
# [1] 53.72143
# [1] 53.7179
# [1] 53.71452
# [1] 53.71128
# [1] 53.70818
# [1] 53.70522
# [1] 53.70238
# [1] 53.69966
# [1] 53.69706
# [1] 53.69457
# [1] 53.69219
# [1] 53.68991
# [1] 53.68773
# [1] 53.68564
# [1] 53.68364
# [1] 53.68172
# [1] 53.67989
# [1] 53.67813
# [1] 53.67645
# [1] 53.67485
# [1] 53.67331
# [1] 53.67184
# [1] 53.67043
# [1] 53.66908
# [1] 53.66778
# [1] 53.66655
# [1] 53.66536
# [1] 53.66423
# [1] 53.66315
# [1] 53.66211
# [1] 53.66111
# [1] 53.66016
# [1] 53.65925
# [1] 53.65838
# [1] 53.65755
# [1] 53.65675
# [1] 53.65598
# [1] 53.65525
# [1] 53.65455
# [1] 53.65388
# [1] 53.65324
# [1] 53.65262
# [1] 53.65204
# [1] 53.65147
# [1] 53.65093
# [1] 53.65042
# [1] 53.64992
# [1] 53.64945
# [1] 53.649
# [1] 53.64857
# [1] 53.64815
# [1] 53.64775
# [1] 53.64737
# [1] 53.64701
# [1] 53.64666
# [1] 53.64633
# [1] 53.64601
# [1] 53.6457
# [1] 53.64541
# [1] 53.64513
# [1] 53.64486
# [1] 53.64461
# [1] 53.64436
# [1] 53.64413
# [1] 53.6439
# [1] 53.64369
# [1] 53.64348
# [1] 53.64328
# [1] 53.6431
# [1] 53.64291
# [1] 53.64274
# [1] 53.64258
# [1] 53.64242
# [1] 53.64227
# [1] 53.64212
# [1] 53.64198
# [1] 53.64185
# [1] 53.64172
# [1] 53.6416
# [1] 53.64148
# [1] 53.64137
# [1] 53.64126
# [1] 53.64116
# [1] 53.64106
# [1] 53.64097
# [1] 53.64088
# [1] 53.64079
# [1] 53.64071
# [1] 53.64063
# [1] 53.64056
# [1] 53.64049
# [1] 53.64042
# [1] 53.64035
# [1] 53.64029
# [1] 53.64023
# [1] 53.64017
# [1] 53.64011
# [1] 53.64006
# [1] 53.64001
# [1] 53.63996
# [1] 53.63991
# [1] 53.63987
# [1] 53.63983
# [1] 53.63978
# [1] 53.63975
# [1] 53.63971
# [1] 53.63967
# [1] 53.63964
# [1] 53.6396
# [1] 53.63957
# [1] 53.63954
# [1] 53.63951
# [1] 53.63949
# The  real coefficents are: -5 -3 4 5 10
# The  final coefficents are: -5.014879 -3.301647 4.297572 4.847053 9.969746
# Iteration No.: 272
